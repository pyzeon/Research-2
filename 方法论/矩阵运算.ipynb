# %% [markdown]
# # 迹
#
# $n\times n$ 的方阵 $\mathbf{A}$ 的 **迹（Trace）** 定义为主对角线元素的和 $\operatorname{tr}(\mathbf{A}) = \sum\limits_{i=1}^{n}a_{i,i}$。
#
# 迹的性质：
# * $\operatorname{tr}(\mathbf{A}') = \operatorname{tr}(\mathbf{A})$
# * $\operatorname{tr}(\mathbf{A} + \mathbf{B}) = \operatorname{tr}(\mathbf{A}) + \operatorname{tr}(\mathbf{B})$
# * $\operatorname{tr}(k\mathbf{A}) = k\operatorname{tr}(\mathbf{A})$
# * $\operatorname{tr}(\mathbf{A}\mathbf{B}) = \operatorname{tr}(\mathbf{B}\mathbf{A})$

# %% [markdown]
# # 秩
#
# $n\times k$ 的矩阵 $\mathbf{A}$ 的 **秩（Rank）** 定义为线性独立的最大列数，记为 $\operatorname{rank}(\mathbf{A})$。
#
# 秩的性质：
# * $\operatorname{rank}(\mathbf{A}') = \operatorname{rank}(\mathbf{A})$，此也说明矩阵的行秩等于列秩。
# * $\mathbf{A}$ 是 $n\times k$ 的矩阵，则 $\operatorname{rank}(\mathbf{A})\leq\min\{n,k\}$

# %% [markdown]
# # 逆
#
# ## Sherman-Morrison-Woodbury 公式
#
# **Sherman-Morrison 公式**：$n\times n$ 的方阵 $\mathbf{A}$ 可逆，$\mathbf{u},\mathbf{v}$ 是 $n\times 1$ 的列向量，则矩阵 $\mathbf{A}+\mathbf{u}\mathbf{v}'$ 可逆：
# $$
# \left(\mathbf{A}+\mathbf{u}\mathbf{v}'\right)^{-1} = \mathbf{A}^{-1} - \mathbf{A}^{-1}\mathbf{u}\left(1+\mathbf{v}'\mathbf{A}^{-1}\mathbf{u}\right)^{-1}\mathbf{v}'\mathbf{A}^{-1}
# $$
# **证明**：通过解线性方程组证明。考虑如下的线性方程问题：
# $$
# \left(\mathbf{A}+\mathbf{u}\mathbf{v}'\right)\mathbf{x} = \mathbf{b}
# $$
# 两边同时左乘以 $\mathbf{A}^{-1}$，并令 $\alpha = \mathbf{v}'\mathbf{x}$：
# \begin{equation}\label{SMW-1}
# \mathbf{x} + (\mathbf{A}^{-1}\mathbf{u})\mathbf{v}'\mathbf{x} = \mathbf{x} + (\mathbf{A}^{-1}\mathbf{u})\alpha = \mathbf{A}^{-1}\mathbf{b}
# \end{equation}
# 两边再同时左乘以 $\mathbf{v}'$：
# $$
# \alpha\cdot\left(1 + \mathbf{v}'\mathbf{A}^{-1}\mathbf{u}\right) = \mathbf{v}'\mathbf{A}^{-1}\mathbf{b}
# $$
# 从而：
# $$
# \alpha = \left(1 + \mathbf{v}'\mathbf{A}^{-1}\mathbf{u}\right)^{-1}\mathbf{v}'\mathbf{A}^{-1}\mathbf{b}
# $$
# 代入 (\ref{SMW-1}) 式得：
# $$
# \mathbf{x} = \left[\mathbf{A}^{-1} - \mathbf{A}^{-1}\mathbf{u}\left(1+\mathbf{v}'\mathbf{A}^{-1}\mathbf{u}\right)^{-1}\mathbf{v}'\mathbf{A}^{-1}\right]\mathbf{b}
# $$
#
# **Sherman-Morrison-Woodbury 公式**：
# * $n\times n$ 的方阵 $\mathbf{A}$ 可逆，$\mathbf{U},\mathbf{V}$ 均是 $n\times k$ 的矩阵，则矩阵 $\mathbf{A}+\mathbf{U}\mathbf{V}'$ 可逆：
# $$
# \left(\mathbf{A}+\mathbf{U}\mathbf{V}'\right)^{-1} = \mathbf{A}^{-1} - \mathbf{A}^{-1}\mathbf{U}\left(\mathbf{I}+\mathbf{V}'\mathbf{A}^{-1}\mathbf{U}\right)^{-1}\mathbf{V}'\mathbf{A}^{-1}
# $$
# * $n\times n, k\times k$ 的方阵 $\mathbf{A},\mathbf{B}$ 可逆，$\mathbf{U},\mathbf{V}$ 均是 $n\times k$ 的矩阵，则矩阵 $\mathbf{A}+\mathbf{U}\mathbf{B}\mathbf{V}'$ 可逆：
# $$
# \left(\mathbf{A}+\mathbf{U}\mathbf{B}\mathbf{V}'\right)^{-1} = \mathbf{A}^{-1} - \mathbf{A}^{-1}\mathbf{U}\left(\mathbf{B}^{-1}+\mathbf{V}'\mathbf{A}^{-1}\mathbf{U}\right)^{-1}\mathbf{V}'\mathbf{A}^{-1}
# $$

# %% [markdown]
# # 置换阵
#
# **置换（Permutation）** 定义为一个集合到自身的双射：
# $$
# \pi:\ \{1,\ldots,n\}\to\{1,\ldots,n\}
# $$
# 具体表示为：
# $$
# \begin{pmatrix} 1 & 2 & \cdots & n \\ \pi(1) & \pi(2) & \cdots & \pi(n) \end{pmatrix}
# $$
#
# $n\times n$ 的方阵 $\mathbf{P}$ 称为 **置换阵（Permutation Matrix）**，如果 $\mathbf{P}$ 的所有元素均为 0 或者 1，并且每一行每一列均只有一个 1。
#
# 置换阵与置换的关系：从单位阵 $\mathbf{I}$ 出发，对 $\mathbf{I}$ 的行按照置换 $\pi$ 进行交换即得到一个行置换阵：
# $$
# \mathbf{P}_\pi = \begin{pmatrix} \boldsymbol{\iota}'_{\pi(1)} \\ \boldsymbol{\iota}'_{\pi(2)} \\ \vdots \\ \boldsymbol{\iota}'_{\pi(n)} \end{pmatrix}
# $$
# 其中，$\boldsymbol{\iota}_i$ 是第 i 个元素为 1 其他元素为 0 的列向量，$\mathbf{P}_\pi$ 的元素为：
# $$
# \mathbf{P}_{i,j} = \left\{\begin{aligned}
# & 1,\ i=\pi(j)\\
# & 0,\ i\neq\pi(j)
# \end{aligned}\right.
# $$
# 对 $\mathbf{I}$ 的列按照置换 $\pi$ 进行交换得到一个列置换阵：
# $$
# \mathbf{Q}_\pi = \begin{pmatrix} \boldsymbol{\iota}_{\pi(1)} & \boldsymbol{\iota}_{\pi(2)} & \cdots & \boldsymbol{\iota}_{\pi(n)} \end{pmatrix}
# $$
# $\mathbf{Q}_\pi$ 的元素为：
# $$
# \mathbf{Q}_{i,j} = \left\{\begin{aligned}
# & 1,\ j=\pi(i)\\
# & 0,\ j\neq\pi(i)
# \end{aligned}\right.
# $$
# 由于置换阵是由标准正交基组成的，所以置换阵都是正交阵。记置换 $\pi$ 的逆置换为 $\pi^{-1}$，则行置换阵 $\mathbf{P}_\pi$ 和列置换阵 $\mathbf{Q}_\pi$ 的关系：
# $$
# \mathbf{Q}_\pi = \mathbf{P}^{-1}_\pi = \mathbf{P}'_\pi = \mathbf{P}_{\pi^{-1}}
# $$
#
#
# 置换阵的性质：
# * 行置换阵左乘列向量 $\mathbf{x}$ 是将 $\mathbf{x}$ 的元素按照 $\pi$ 进行置换：
# $$
# \mathbf{P}_\pi\mathbf{x} = \begin{pmatrix} x_{\pi(1)} \\ x_{\pi(2)} \\ \vdots \\ x_{\pi(n)} \end{pmatrix}
# $$
# 同样，行置换阵左乘一个矩阵也是将其行按照 $\pi$ 进行置换。
# * 列置换阵右乘行向量 $\mathbf{x}$ 是将 $\mathbf{x}$ 的元素按照 $\pi$ 进行置换：
# $$
# \mathbf{x}'\mathbf{Q}_\pi = \begin{pmatrix} x_{\pi(1)} & x_{\pi(2)} & \cdots & x_{\pi(n)} \end{pmatrix}
# $$
# 同样，列置换阵右乘一个矩阵也是将其列按照 $\pi$ 进行置换。
# * 对于两个置换 $\pi,\sigma$，其复合置换 $\pi\circ\sigma$ 的行置换阵为：
# $$
# \mathbf{P}_{\pi\circ\sigma} = \mathbf{P}_\sigma\mathbf{P}_\pi
# $$
# 列置换阵为：
# $$
# \mathbf{Q}_{\pi\circ\sigma} = \mathbf{Q}_\pi\mathbf{Q}_\sigma
# $$

# %% [markdown]
# # 分块矩阵
#
# <a id='InvOfBlockMatrix'></a>
# ## 逆
#
# ### 两个非零分块
#
# \begin{lemma}
# $T = \begin{pmatrix} A & 0 \\ 0 & D \end{pmatrix}$ 是分块方阵，若 A, D 可逆，则 T 可逆，且 $T^{-1}=\begin{pmatrix} A^{-1} & 0 \\ 0 & D^{-1} \end{pmatrix}$;
# \end{lemma}
#
# \begin{lemma}
# $T = \begin{pmatrix} 0 & B \\ C & 0 \end{pmatrix}$ 是分块方阵，若 B, C 可逆，则 T 可逆，且 $T^{-1}=\begin{pmatrix} 0 & C^{-1} \\ B^{-1} & 0 \end{pmatrix}$;
# \end{lemma}
#
# ### 三个非零分块
#
# \begin{theorem}
# $T = \begin{pmatrix} A & B \\ 0 & D \end{pmatrix}$ 是分块方阵，若 A, D 可逆，则 T 可逆，且 $T^{-1}=\begin{pmatrix} A^{-1} & -A^{-1}BD^{-1} \\ 0 & D^{-1} \end{pmatrix}$;
# \end{theorem}
#
# \begin{theorem}
# $T = \begin{pmatrix} A & 0 \\ C & D \end{pmatrix}$ 是分块方阵，若 A, D 可逆，则 T 可逆，且 $T^{-1}=\begin{pmatrix} A^{-1} & 0 \\ -D^{-1}CA^{-1} & D^{-1} \end{pmatrix}$;
# \end{theorem}
#
# \begin{theorem}
# $T = \begin{pmatrix} A & B \\ C & 0 \end{pmatrix}$ 是分块方阵，若 B, C 可逆，则 T 可逆，且 $T^{-1}=\begin{pmatrix} 0 & C^{-1} \\ B^{-1} & -B^{-1}AC^{-1} \end{pmatrix}$;
# \end{theorem}
#
# \begin{theorem}
# $T = \begin{pmatrix} 0 & B \\ C & D \end{pmatrix}$ 是分块方阵，若 B, C 可逆，则 T 可逆，且 $T^{-1}=\begin{pmatrix} -C^{-1}DB^{-1} & C^{-1} \\ B^{-1} & 0 \end{pmatrix}$;
# \end{theorem}
#
# ### 四个非零分块
#
# \begin{theorem}
# 分块方阵 $T = \begin{pmatrix} A & B \\ C & D \end{pmatrix}$ 可逆，若 A 可逆，则 $(D-CA^{-1}B)^{-1}$ 存在，且
# $$
# T^{-1}=\begin{pmatrix}
# A^{-1}+A^{-1}B(D-CA^{-1}B)^{-1}CA^{-1} & -A^{-1}B(D-CA^{-1}B)^{-1} \\ -(D-CA^{-1}B)^{-1}CA^{-1} & (D-CA^{-1}B)^{-1}
# \end{pmatrix}
# $$;
# \end{theorem}
#
# \begin{theorem}
# 分块方阵 $T = \begin{pmatrix} A & B \\ C & D \end{pmatrix}$ 可逆，若 D 可逆，则 $(A-BD^{-1}C)^{-1}$ 存在，且
# $$
# T^{-1}=\begin{pmatrix}
# (A-BD^{-1}C)^{-1} & -(A-BD^{-1}C)^{-1}BD^{-1} \\ -D^{-1}C(A-BD^{-1}C)^{-1} & D^{-1}+D^{-1}C(A-BD^{-1}C)^{-1}BD^{-1}
# \end{pmatrix}
# $$;
# \end{theorem}
#
# \begin{theorem}
# 分块方阵 $T = \begin{pmatrix} A & B \\ C & D \end{pmatrix}$ 可逆，若 B 可逆，则 $(C-DB^{-1}A)^{-1}$ 存在，且
# $$
# T^{-1}=\begin{pmatrix}
# -(C-DB^{-1}A)^{-1}DB^{-1} & (C-DB^{-1}A)^{-1} \\ B^{-1}+B^{-1}A(C-DB^{-1}A)^{-1}DB^{-1} & -B^{-1}A(C-DB^{-1}A)^{-1}
# \end{pmatrix}
# $$;
# \end{theorem}
#
# \begin{theorem}
# 分块方阵 $T = \begin{pmatrix} A & B \\ C & D \end{pmatrix}$ 可逆，若 C 可逆，则 $(B-AC^{-1}D)^{-1}$ 存在，且
# $$
# T^{-1}=\begin{pmatrix}
# -C^{-1}D(B-AC^{-1}D)^{-1} & C^{-1}+C^{-1}D(B-AC^{-1}D)^{-1}AC^{-1} \\ (B-AC^{-1}D)^{-1} & -(B-AC^{-1}D)^{-1}AC^{-1}
# \end{pmatrix}
# $$;
# \end{theorem}
# **证明**：待定法证明。设 $T^{-1} = \begin{pmatrix} A & B \\ C & D \end{pmatrix}$，则有：
# $$
# T\cdot T^{-1} = \begin{pmatrix} AX+BZ & AY+BW \\ CX+DZ & CY+DW \end{pmatrix} = \begin{pmatrix} I & 0 \\ 0 & I \end{pmatrix}
# $$
# 从而：
# $$
# \left\{
# \begin{aligned}
# & AX+BZ=I\\
# & AY+BW=0\\
# & CX+DZ=0\\
# & CY+DW=I
# \end{aligned}
# \right.
# $$
# 由第三个方程得：$X=-C^{-1}DZ$，代入第一个方程得：
# $$
# (B-AC^{-1}D)Z=I
# $$
# 从而 $(B-AC^{-1}D)$ 可逆，并且：
# $$
# Z = (B-AC^{-1}D)^{-1}, X=-C^{-1}D(B-AC^{-1}D)^{-1}
# $$
# 由第四个方程得：
# $$
# Y = C^{-1}(I-DW)
# $$
# 代入第二个方程得：
# $$
# W=-(B-AC^{-1}D)^{-1}AC^{-1}
# $$
# 最后可得：
# $$
# Y = C^{-1}+C^{-1}D(B-AC^{-1}D)^{-1}AC^{-1}$$
# 其他结果可类似证明。

# %% [markdown]
# ## 行列式
#
# \begin{theorem}
# $P = \begin{pmatrix} A & B \\ C & D \end{pmatrix}$ 是分块 n 阶方阵，其中 A 为 $n_1$ 阶方阵，D 为 $n_2$ 阶方阵，B、C 分别为 $n_1\times n_2$ 和 $n_2\times n_1$ 阶矩阵，则：
# \begin{itemize}
# \item 若 A 可逆，则 $|P|=|A|\cdot|D-CA^{-1}B|$;
# \item 若 D 可逆，则 $|P|=|D|\cdot|A-BD^{-1}C|$;
# \end{itemize}
# \end{theorem}

# %% [markdown]
# <a id='KroneckerProduct'></a>
#
# # 克罗内克积
#
# $n\times k$ 的矩阵 $\mathbf{A}$ 和 $m\times l$ 的矩阵 $\mathbf{B}$ 的 **克罗内克积（Kronecker Product）** 定义为 $nm\times kl$ 维的分块矩阵：
# $$
# \mathbf{A}\otimes\mathbf{B} = \begin{pmatrix} a_{1,1}\mathbf{B} & \cdots & a_{1,k}\mathbf{B} \\ \vdots & \ddots & \vdots \\ a_{n,1}\mathbf{B} & \cdots & a_{n,k}\mathbf{B} \end{pmatrix}
# $$
#
# 克罗内克积的性质：
# * 双线性性：
# $$
# \begin{aligned}
# & \mathbf{A}\otimes(\mathbf{B}+\mathbf{C}) = \mathbf{A}\otimes\mathbf{B} + \mathbf{A}\otimes\mathbf{C}\\
# & (\mathbf{A}+\mathbf{B})\otimes\mathbf{C} = \mathbf{A}\otimes\mathbf{C} + \mathbf{B}\otimes\mathbf{C}\\
# & (k\mathbf{A})\otimes\mathbf{B} = \mathbf{A}\otimes(k\mathbf{B}) = k(\mathbf{A}\otimes\mathbf{B})
# \end{aligned}
# $$
# * 结合律：
# $$
# \mathbf{A}\otimes(\mathbf{B}\otimes\mathbf{C}) = (\mathbf{A}\otimes\mathbf{B})\otimes\mathbf{C}
# $$
# * 置换等价性：$\mathbf{A}\otimes\mathbf{B}$ 和 $\mathbf{B}\otimes\mathbf{A}$ 是置换等价的，即存在置换阵 $\mathbf{P}$ 和 $\mathbf{Q}$ 使得：
# $$
# \mathbf{A}\otimes\mathbf{B} = \mathbf{P}\left(\mathbf{B}\otimes\mathbf{A}\right)\mathbf{Q}
# $$
# 特别的，如果 $\mathbf{A},\mathbf{B}$ 是方阵，则可取 $\mathbf{Q}=\mathbf{P}$，即 $\mathbf{A}\otimes\mathbf{B}$ 和 $\mathbf{B}\otimes\mathbf{A}$ 是相似的。
# * 混合乘积性质：矩阵乘积 $\mathbf{A}\mathbf{C}$ 和 $\mathbf{B}\mathbf{D}$ 存在，则：
# $$
# (\mathbf{A}\otimes\mathbf{B})\cdot(\mathbf{C}\otimes\mathbf{D}) = (\mathbf{A}\cdot\mathbf{C})\otimes(\mathbf{B}\cdot\mathbf{D})
# $$
# * 转置：
# $$
# (\mathbf{A}\otimes\mathbf{B})' = \mathbf{A}'\otimes\mathbf{B}'
# $$
# * 逆：
# $$
# (\mathbf{A}\otimes\mathbf{B})^{-1} = \mathbf{A}^{-1}\otimes\mathbf{B}^{-1}
# $$
# * 矩阵方程：矩阵方程 $\mathbf{A}\mathbf{X}\mathbf{B}=\mathbf{C}$ 可通过下式化成普通的线性方程组
# $$
# \operatorname{vec}(\mathbf{A}\mathbf{X}\mathbf{B}) = (\mathbf{B}'\otimes\mathbf{A})\cdot\operatorname{vec}(\mathbf{X}) = \operatorname{vec}(\mathbf{C})
# $$
# 其中，$\operatorname{vec}$ 是向量化算子，它返回的是把矩阵的所有列堆起来所形成的列向量。

# %% [markdown]
# # 对称阵
#
# ## 正定阵
#
# 正定阵和半正定阵的性质
# * 正定阵的主对角线元素严格为正，半正定阵的主对角线元素均非负。
# * $\mathbf{A}$ 正定阵，则 $\mathbf{A}^{-1}$ 存在且正定。
# * $\mathbf{X}$ 是 $n\times k$ 的矩阵，则 $\mathbf{X}'\mathbf{X}$ 与 $\mathbf{X}\mathbf{X}'$ 都是半正定阵。
# * $\mathbf{X}$ 是 $n\times k$ 的矩阵，若其列满秩 $\operatorname{rank}(\mathbf{X}) = k$，则 $\mathbf{X}'\mathbf{X}$ 是正定阵；若其行满秩 $\operatorname{rank}(\mathbf{X}) = n$，则 $\mathbf{X}\mathbf{X}'$ 是正定阵。

# %% [markdown]
# ## 幂等阵
#
# $n\times n$ 的对称阵 $\mathbf{A}$ 称为 **幂等阵（Idempotent Matrix）**，如果有 $\mathbf{A}\cdot\mathbf{A}=\mathbf{A}$。
#
# 幂等阵的性质：
# * $\operatorname{rank}(\mathbf{A})=\operatorname{tr}(\mathbf{A})$
# * 幂等阵是半正定阵。
# * $\mathbf{X}$ 是 $n\times k, n\geq k$ 的列满秩矩阵，$\operatorname{rank}(\mathbf{X})=k$，则下面的两个矩阵为幂等阵：
# $$
# \begin{aligned}
# & \mathbf{P} = \mathbf{X}(\mathbf{X}'\mathbf{X})^{-1}\mathbf{X}'\\
# & \mathbf{M} = \mathbf{I} - \mathbf{P} = \mathbf{X}(\mathbf{X}'\mathbf{X})^{-1}\mathbf{X}'
# \end{aligned}
# $$
# 并且 $\operatorname{rank}(P) = k$，$\operatorname{rank}(M) = n-k$。上述两个矩阵出现在多元线性回归中，如果 $\mathbf{X}$ 是自变量组成的矩阵，则 $\mathbf{P}$ 是向 $\mathbf{X}$ 列向量张成的线性空间投影的投影矩阵，即 $\mathbf{y}$ 对 $\mathbf{X}$ 的回归系数为 $(\mathbf{X}'\mathbf{X})^{-1}\mathbf{X}'\cdot\mathbf{y}$，$\mathbf{y}$ 的投影向量为 $\hat{\mathbf{y}} = \mathbf{P}\cdot\mathbf{y}$，残差向量为 $\hat{\mathbf{u}} = \mathbf{y} - \hat{\mathbf{y}} = \mathbf{M}\cdot\mathbf{y}$。
